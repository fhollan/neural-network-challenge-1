# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# !pip install pandas scikit-learn
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y= loans_df['credit_ranking']

# Display a sample of y
print(y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking

X = loans_df.drop(columns=['credit_ranking'])
# Review the features DataFrame
X
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Assign the function a random_state equal to 1

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)


# Fit the scaler to the features training dataset
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
#Define input features
input_features = len(X_train.columns)
input_features
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
layer_1 = 4

# Define the number of hidden nodes for the second hidden layer
layer_2 = 2

# Define the number of neurons in the output layer
output = 1

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()




# Add the first hidden layer
nn_model.add(tf.keras.layers.Dense(units=layer_1, activation="relu", input_dim=input_features))

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(units=layer_2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(units=output, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 48
#
#  dense_1 (Dense)             (None, 2)                 10
#
#  dense_2 (Dense)             (None, 1)                 3
#
# ...
# Total params: 61 (244.00 Byte)
# Trainable params: 61 (244.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
nn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X, y))
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 14ms/step - loss: 3.3516 - accuracy: 0.4637 - val_loss: 2.7788 - val_accuracy: 0.4653
# Epoch 2/50
# 38/38 [==============================] - 0s 7ms/step - loss: 2.2481 - accuracy: 0.4637 - val_loss: 1.8263 - val_accuracy: 0.4678
# Epoch 3/50
# 38/38 [==============================] - 0s 7ms/step - loss: 1.4557 - accuracy: 0.4696 - val_loss: 1.1660 - val_accuracy: 0.4765
# Epoch 4/50
# 38/38 [==============================] - 0s 7ms/step - loss: 0.9435 - accuracy: 0.4862 - val_loss: 0.7836 - val_accuracy: 0.5003
# Epoch 5/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7143 - accuracy: 0.5379 - val_loss: 0.6790 - val_accuracy: 0.5572
# Epoch 6/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6734 - accuracy: 0.5947 - val_loss: 0.6729 - val_accuracy: 0.5860
# Epoch 7/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X,y,verbose=2)
loss, accuracy = nn_model.evaluate(X_test, y_test)


# Display the model loss and accuracy results
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# 50/50 - 0s - loss: 0.6685 - accuracy: 0.5997 - 101ms/epoch - 2ms/step
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6845 - accuracy: 0.6000
# Test Loss: 0.6845142841339111, Test Accuracy: 0.6000000238418579

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
nn_model.save(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test,verbose=2)


# Display a sample of the predictions

print(predictions[:10])
# Out:
# 13/13 - 0s - 37ms/epoch - 3ms/step
# [[0.56349623]
#  [0.45419917]
#  [0.6522736 ]
#  [0.46857762]
#  [0.61531734]
#  [0.6095763 ]
#  [0.57126456]
#  [0.31251332]
#  [0.61413306]
#  [0.6531456 ]]

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          1.0
# 397          1.0
# 398          0.0
# 399          0.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
#type(y_test)
#type(predictions)
predictions_df['predictions']
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0
#       ...
# 395    1.0
# 396    1.0
# 397    1.0
# 398    0.0
# 399    0.0
# Name: predictions, Length: 400, dtype: float32

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df['predictions']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.49      0.53       188
#            1       0.61      0.70      0.65       212
#
#     accuracy                           0.60       400
#    macro avg       0.60      0.59      0.59       400
# weighted avg       0.60      0.60      0.60       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# Types of recommendation systems are...
#
# -Collaborative filtering methods-uses data collected *purchaces, hobbies, or intrests* to suggest what a user might be intrested in purchacing
#
# -Content-based filtering- suggests items based on past experiences
#
# -Context-based filtering- sequence of actions combined with context
#
# The data I would need to suggest student loan options would be...
#
#
# - if social networks indicate that friends/family are attending classes* user more likely to attend classes if peers are attending.
# -user is looking to further job-skills or open to new work* user may be willing to take on a financial hardship to gain experienced work.
# -financial income* offering flexability in payments may be a perk to user
# -military background* discounts or family options could be provided
# -personal intrests* such as technology, investing, business, medical research*,
#
#
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# A hybrid data collection system would be used. Seeing that most of the variables are collaborative there are some aspects that are content-based. This allows the data to be used to help the user decide if a financial burden is worth the risk and relevent to their personal growth/gain.
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
# 1. Discrimination- the act of not allowing a group of users to access loans or denying a user based on protected class.
#
# 2. Age groups- often younger students either rely on parents income or have no credit/income information. This would be a challenge to offer a loan.
